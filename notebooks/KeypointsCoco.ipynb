# %%
from ultralytics import YOLO

# %%
yaml_path = 'yolo/data.yaml'

yolo = YOLO('yolov8n-pose.pt')

# %%
yolo.train(data=yaml_path, epochs=100, project='./yolo', name='yolov8n')
# Out:
# Ultralytics YOLOv8.2.45  Python-3.10.2 torch-2.2.1+cpu CPU (13th Gen Intel Core(TM) i7-1360P)
# ...
